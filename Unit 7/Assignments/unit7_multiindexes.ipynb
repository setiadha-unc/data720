# %% [markdown]
# # Graded: 5 of 5 correct
# - [x] Display head
# - [x] Sort by listed columns
# - [x] Set index to listed columns
# - [x] Group by `cut` and `clarity` using `mean`
# - [x] `VVS1` cross-section
#
# Comments:

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# The next cell loads the `diamonds` dataset from Seaborn

# %%
data = sns.load_dataset('diamonds')

# %% [markdown]
# Display the first 5 rows of `data`

# %%
data.head(5)
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# Sort `data` by ALL of the columns `cut`, `clarity`, and `color` columns. Then create a MultiIndex by setting the index of `data` to ALL `cut`, `clarity`, and `color`. Display the first 5 rows of `data`.

# %%
# sort data by ALL the columns cut, clarity, and color
data.sort_values(["cut", "clarity", "color"])
# Out:
#        carat    cut color clarity  depth  table  price     x     y     z
# 3680    0.51  Ideal     D      IF   62.0   56.0   3446  5.14  5.18  3.20
# 3682    0.51  Ideal     D      IF   62.1   55.0   3446  5.12  5.13  3.19
# 4000    0.53  Ideal     D      IF   61.5   54.0   3517  5.27  5.21  3.22
# 5345    0.53  Ideal     D      IF   62.2   55.0   3812  5.17  5.19  3.22
# 5457    0.63  Ideal     D      IF   61.2   53.0   3832  5.55  5.60  3.41
# ...      ...    ...   ...     ...    ...    ...    ...   ...   ...   ...
# 46575   1.00   Fair     J      I1   65.0   59.0   1784  6.27  6.17  4.05
# 46679   0.99   Fair     J      I1   73.6   60.0   1789  6.01  5.80  4.35
# 47802   0.99   Fair     J      I1   62.9   58.0   1901  6.33  6.10  3.91
# 50791   0.96   Fair     J      I1   59.5   60.0   2304  6.28  6.23  3.72
# 50953   0.95   Fair     J      I1   64.9   56.0   2322  6.17  6.12  3.99
#
# [53940 rows x 10 columns]

# %%
# Create multiundex Cut, Clarity, and Color.
data = data.set_index(["cut", "clarity", "color"])

# %%
print(data)
# Out:
#                          carat  depth  table  price     x     y     z
# cut       clarity color
# Ideal     SI2     E       0.23   61.5   55.0    326  3.95  3.98  2.43
# Premium   SI1     E       0.21   59.8   61.0    326  3.89  3.84  2.31
# Good      VS1     E       0.23   56.9   65.0    327  4.05  4.07  2.31
# Premium   VS2     I       0.29   62.4   58.0    334  4.20  4.23  2.63
# Good      SI2     J       0.31   63.3   58.0    335  4.34  4.35  2.75
# ...                        ...    ...    ...    ...   ...   ...   ...
# Ideal     SI1     D       0.72   60.8   57.0   2757  5.75  5.76  3.50
# Good      SI1     D       0.72   63.1   55.0   2757  5.69  5.75  3.61
# Very Good SI1     D       0.70   62.8   60.0   2757  5.66  5.68  3.56
# Premium   SI2     H       0.86   61.0   58.0   2757  6.15  6.12  3.74
# Ideal     SI2     D       0.75   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 7 columns]

# %% [markdown]
# Group `data` by `cut` and `clarity` using the `mean` function, and save the result as a variable `grouped`. Display `grouped`.

# %%
grouped = data.groupby(['cut', 'clarity'], observed=False).mean()

# %%
grouped
# Out:
#                       carat      depth      table        price         x  \
# cut       clarity
# Ideal     IF       0.455041  61.645710  55.707013  2272.913366  4.827261
#           VVS1     0.495960  61.679091  55.839912  2468.129458  4.960596
#           VVS2     0.586213  61.690714  55.915848  3250.290100  5.214693
#           VS1      0.674714  61.706436  55.894037  3489.744497  5.449746
#           VS2      0.670566  61.730901  55.931256  3284.550385  5.428111
#           SI1      0.801808  61.737482  56.061023  3752.118169  5.781287
#           SI2      1.007925  61.701001  56.120516  4755.952656  6.262621
#           I1       1.222671  61.648630  56.102740  4335.726027  6.751712
# Premium   IF       0.603478  61.047826  58.730435  3856.143478  5.234957
#           VVS1     0.534821  61.260877  58.674513  2831.206169  5.037955
#           VVS2     0.654724  61.280230  58.654483  3795.122989  5.390920
#           VS1      0.793308  61.318451  58.690397  4485.462041  5.738049
# ...

# %% [markdown]
# Display a cross-section of `grouped` using the `VVS1` clarity.

# %%
grouped.xs("VVS1", level="clarity")
# Out:
#               carat      depth      table        price         x         y  \
# cut
# Ideal      0.495960  61.679091  55.839912  2468.129458  4.960596  4.978012
# Premium    0.534821  61.260877  58.674513  2831.206169  5.037955  5.018847
# Very Good  0.494588  61.675919  57.622687  2459.441065  4.895513  4.927503
# Good       0.502312  62.123118  58.922581  2254.774194  4.926290  4.950806
# Fair       0.664706  60.417647  61.235294  3871.352941  5.503529  5.508824
#
#                   z
# cut
# Ideal      3.064304
# Premium    3.080000
# Very Good  3.031420
# Good       3.068602
# Fair       3.327647
