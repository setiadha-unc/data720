# %%
import pandas as pd
import os 
import shutil

# %%
myFile = "CountyHealthData_2014-2015.csv"
os.path.isfile(myFile)
# Out:
# True

# %%
myData = pd.read_csv(myFile)

# %%
myData.shape
# Out:
# (6109, 64)

# %%
myData.dtypes
# Out:
# State                                object
# Region                               object
# Division                             object
# County                               object
# FIPS                                  int64
#                                      ...
# Other primary care providers        float64
# Median household income               int64
# Children eligible for free lunch    float64
# Homicide rate                       float64
# Inadequate social support           float64
# Length: 64, dtype: object

# %%
myData.head()
# Out:
#   State Region Division                      County  FIPS  GEOID   SMS Region  \
# 0    AK   West  Pacific  Aleutians West Census Area  2016   2016  Insuff Data
# 1    AK   West  Pacific  Aleutians West Census Area  2016   2016  Insuff Data
# 2    AK   West  Pacific           Anchorage Borough  2020   2020    Region 22
# 3    AK   West  Pacific           Anchorage Borough  2020   2020    Region 22
# 4    AK   West  Pacific          Bethel Census Area  2050   2050  Insuff Data
#
#        Year  Premature death  Poor or fair health  ...  Drug poisoning deaths  \
# 0  1/1/2014              NaN                0.122  ...                    NaN
# 1  1/1/2015              NaN                0.122  ...                    NaN
# 2  1/1/2014           6827.0                0.125  ...                  15.37
# 3  1/1/2015           6856.0                0.125  ...                  17.08
# 4  1/1/2014          13345.0                0.211  ...                    NaN
#
# ...

# %%
myData.tail()
# Out:
#      State Region  Division           County   FIPS  GEOID   SMS Region  \
# 6104    WY   West  Mountain     Uinta County  56041  56041  Insuff Data
# 6105    WY   West  Mountain  Washakie County  56043  56043  Insuff Data
# 6106    WY   West  Mountain  Washakie County  56043  56043  Insuff Data
# 6107    WY   West  Mountain    Weston County  56045  56045  Insuff Data
# 6108    WY   West  Mountain    Weston County  56045  56045  Insuff Data
#
#           Year  Premature death  Poor or fair health  ...  \
# 6104  1/1/2015           7436.0                0.135  ...
# 6105  1/1/2014           6580.0                0.106  ...
# 6106  1/1/2015           7572.0                0.106  ...
# 6107  1/1/2014           5633.0                0.162  ...
# 6108  1/1/2015           7819.0                0.162  ...
#
#       Drug poisoning deaths  Uninsured adults  Uninsured children  \
# 6104                  18.66             0.192               0.090
# ...

# %%
myDataSample = myData.sample(3)

# %%
myDataSample
# Out:
#      State     Region            Division             County   FIPS  GEOID  \
# 3707    NH  Northeast         New England  Rockingham County  33015  33015
# 4073    OH    Midwest  East North Central    Mahoning County  39099  39099
# 241     AR      South  West South Central      Howard County   5061   5061
#
#      SMS Region      Year  Premature death  Poor or fair health  ...  \
# 3707  Region 12  1/1/2015           4955.0                0.098  ...
# 4073  Region 17  1/1/2015           8646.0                0.139  ...
# 241   Region 11  1/1/2015          10956.0                0.189  ...
#
#       Drug poisoning deaths  Uninsured adults  Uninsured children  \
# 3707                  12.77             0.125               0.037
# 4073                  17.36             0.165               0.050
# 241                     NaN             0.305               0.076
#
#       Health care costs  Could not see doctor due to cost  \
# ...

# %%
myData[15:20]
# Out:
#    State Region Division                     County  FIPS  GEOID SMS Region  \
# 15    AK   West  Pacific    Kenai Peninsula Borough  2122   2122  Region 22
# 16    AK   West  Pacific  Ketchikan Gateway Borough  2130   2130  Region 22
# 17    AK   West  Pacific  Ketchikan Gateway Borough  2130   2130  Region 22
# 18    AK   West  Pacific      Kodiak Island Borough  2150   2150  Region 22
# 19    AK   West  Pacific      Kodiak Island Borough  2150   2150  Region 22
#
#         Year  Premature death  Poor or fair health  ...  \
# 15  1/1/2015           6917.0                0.137  ...
# 16  1/1/2014           8422.0                0.144  ...
# 17  1/1/2015           7269.0                0.144  ...
# 18  1/1/2014           6891.0                0.132  ...
# 19  1/1/2015           6075.0                0.132  ...
#
#     Drug poisoning deaths  Uninsured adults  Uninsured children  \
# 15                  15.94             0.278               0.159
# ...

# %%
myData.describe()
# Out:
#                FIPS         GEOID  Premature death  Poor or fair health  \
# count   6109.000000   6109.000000      5984.000000          5424.000000
# mean   30322.714192  30322.714192      8029.289271             0.173321
# std    15177.989515  15177.989515      2413.808811             0.061034
# min     1001.000000   1001.000000      2398.000000             0.045000
# 25%    18163.000000  18163.000000      6351.500000             0.127000
# 50%    29133.000000  29133.000000      7707.500000             0.166000
# 75%    45067.000000  45067.000000      9374.250000             0.209250
# max    56045.000000  56045.000000     25394.000000             0.508000
#
#        Poor physical health days  Poor mental health days  Low birthweight  \
# count                5548.000000              5136.000000      5946.000000
# mean                    3.840465                 3.574474         0.082699
# std                     1.138438                 1.026026         0.021045
# ...

# %%
myData.describe(include='all').round(2)
# Out:
#        State Region        Division             County      FIPS     GEOID  \
# count   6109   6109            6109               6109   6109.00   6109.00
# unique    51      4               9               1830       NaN       NaN
# top       TX  South  South Atlantic  Washington County       NaN       NaN
# freq     469   2803            1175                 60       NaN       NaN
# mean     NaN    NaN             NaN                NaN  30322.71  30322.71
# std      NaN    NaN             NaN                NaN  15177.99  15177.99
# min      NaN    NaN             NaN                NaN   1001.00   1001.00
# 25%      NaN    NaN             NaN                NaN  18163.00  18163.00
# 50%      NaN    NaN             NaN                NaN  29133.00  29133.00
# 75%      NaN    NaN             NaN                NaN  45067.00  45067.00
# max      NaN    NaN             NaN                NaN  56045.00  56045.00
#
# ...

# %%
myData["State"][5:10]
# Out:
# 5    AK
# 6    AK
# 7    AK
# 8    AK
# 9    AK
# Name: State, dtype: object

# %%
myData[["State", "Year", "County", "Uninsured adults"]][20:25]
# Out:
#    State      Year                      County  Uninsured adults
# 20    AK  1/1/2014  Lake and Peninsula Borough             0.434
# 21    AK  1/1/2015  Lake and Peninsula Borough             0.406
# 22    AK  1/1/2014   Matanuska-Susitna Borough             0.266
# 23    AK  1/1/2015   Matanuska-Susitna Borough             0.254
# 24    AK  1/1/2014            Nome Census Area             0.373

# %%
myData.loc[20:25,["State", "Year", "County", "Uninsured adults"]]
# Out:
#    State      Year                      County  Uninsured adults
# 20    AK  1/1/2014  Lake and Peninsula Borough             0.434
# 21    AK  1/1/2015  Lake and Peninsula Borough             0.406
# 22    AK  1/1/2014   Matanuska-Susitna Borough             0.266
# 23    AK  1/1/2015   Matanuska-Susitna Borough             0.254
# 24    AK  1/1/2014            Nome Census Area             0.373
# 25    AK  1/1/2015            Nome Census Area             0.366

# %% [markdown]
# If we use the .iloc attribute before our brackets, pandas accepts two numbers separated by a comma. The first number is for rows and the second for columns. Below, we select the second row and third column.

# %%
myData.iloc[0:3,4:10]
# Out:
#    FIPS  GEOID   SMS Region      Year  Premature death  Poor or fair health
# 0  2016   2016  Insuff Data  1/1/2014              NaN                0.122
# 1  2016   2016  Insuff Data  1/1/2015              NaN                0.122
# 2  2020   2020    Region 22  1/1/2014           6827.0                0.125

# %%
print(myData.Region.shape)
print(myData.Region.dtypes)
# Out:
# (6109,)
# object

# %%
myData.Region.value_counts()
# Out:
# Region
# South        2803
# Midwest      2038
# West          834
# Northeast     434
# Name: count, dtype: int64

# %%
myDataSMS = myData[myData["SMS Region"] == "Insuff Data"]

# %%
myDataSMS
# Out:
#      State Region  Division                      County   FIPS  GEOID  \
# 0       AK   West   Pacific  Aleutians West Census Area   2016   2016
# 1       AK   West   Pacific  Aleutians West Census Area   2016   2016
# 4       AK   West   Pacific          Bethel Census Area   2050   2050
# 5       AK   West   Pacific          Bethel Census Area   2050   2050
# 6       AK   West   Pacific      Dillingham Census Area   2070   2070
# ...    ...    ...       ...                         ...    ...    ...
# 6104    WY   West  Mountain                Uinta County  56041  56041
# 6105    WY   West  Mountain             Washakie County  56043  56043
# 6106    WY   West  Mountain             Washakie County  56043  56043
# 6107    WY   West  Mountain               Weston County  56045  56045
# 6108    WY   West  Mountain               Weston County  56045  56045
#
#        SMS Region      Year  Premature death  Poor or fair health  ...  \
# ...

# %%
ex = myDataSMS.copy()

# %%
ex.loc[0,"County"] = "New County"

# %%
print(ex["County"][0] )
# Out:
# New County

# %%
all(myDataSMS["Region"]==myDataSMS.Region)
# Out:
# True
